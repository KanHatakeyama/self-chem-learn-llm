# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
jsonl_path="data/20240917184419_llm_gen.json"

df=pd.read_json(jsonl_path,lines=True)
df=df.drop(columns=["record","prompt"])
df
# Out:
#       actual_value         CompoundName  \
# 0             0.87    Isopropyl acetate
# 1           112.00  1,3-Propane sultone
# 2           632.00       Caesium iodide
# 3           132.70              unknown
# 4           639.00      Tin(II) bromide
# ...            ...                  ...
# 3205        180.00   Methylcholanthrene
# 3206       -205.00              unknown
# 3207        -80.00     Cycloheptatriene
# 3208          4.22              unknown
# 3209          0.55        2-Furoic acid
#
#                                           SMILES             Property  \
# 0                                   CC(OC(C)C)=O              Density
# 1                                C1COS(=O)(=O)C1  Boiling temperature
# 2                                     [Cs+].[I-]  Melting temperature
# 3                                      C(=O)(N)N  Melting temperature
# 4                                       Br[Sn]Br  Boiling temperature
# ...                                          ...                  ...
# 3205  CC1=C2CCC3=C2C(=CC4=C3C=CC5=CC=CC=C54)C=C1  Melting temperature
# 3206                                   [C-]#[O+]  Melting temperature
# 3207                             C1=C\C/C=C\C=C1  Melting temperature
# 3208                                F[Te](F)(F)F              Density
# 3209                             OC(=O)C1=CC=CO1              Density
#
#          Unit  predicted                                     predicted_text  \
# 0     [g/cm3]       1.83  To predict the density of isopropyl acetate, w...
# 1        [oC]     300.50  To predict the boiling temperature of 1,3-Prop...
# 2        [oC]     621.00  To predict the melting temperature of Caesium ...
# 3        [oC]     122.00  To predict the melting temperature of the give...
# 4        [oC]     623.00  To predict the boiling temperature of Tin(II) ...
# ...       ...        ...                                                ...
# 3205     [oC]       6.65  To predict the melting temperature of Methylch...
# 3206     [oC]      32.50  The given compound is a small, heteroatomic mo...
# 3207     [oC]     108.77  To predict the melting temperature of Cyclohep...
# 3208  [g/cm3]       2.49  To predict the density of the compound F[Te](F...
# 3209  [g/cm3]       1.00  To predict the density of 2-Furoic acid, we ca...
#
#       error_rate
# 0       1.103448
# 1       1.683036
# 2       0.017405
# 3       0.080633
# 4       0.025039
# ...          ...
# 3205    0.963056
# 3206    1.158537
# 3207    2.359625
# 3208    0.409953
# 3209    0.818182
#
# [3210 rows x 8 columns]

# %%
plt.figure(figsize=(15, 5))
sns.histplot(df[df["error_rate"]<2], x="error_rate", hue="Property", multiple="stack", 
             bins=20)
# Out:
# <Axes: xlabel='error_rate', ylabel='Count'>
